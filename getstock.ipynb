# %%
# %pip install yfinance

# %%
# %pip install pandas
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import pandas as pd

# 替换下面的路径为你的文件路径
file_path = '/Users/terrylin/Downloads/SaleMonDetail.html'

# 读取HTML文件
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# 使用BeautifulSoup解析HTML
soup = BeautifulSoup(html_content, 'html.parser')

tables = soup.find_all('table')

# 直接从HTML字符串读取表格数据
dfs = pd.read_html(html_content)

# `dfs`是一个包含所有表格的DataFrame列表
# 你可以通过索引来访问特定的DataFrame，例如：
df = dfs[0]  # 假设你需要第一个表格
df
# Out:
# /var/folders/mv/gb5rn74j78v1_38s5y252t7w0000gn/T/ipykernel_2579/179218990.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_content)
#      市 場    代碼    股票 名稱     股東會 日期       除息日程                              \
#      市 場    代碼    股票 名稱     股東會 日期     除息 交易日 除息 參考 價   填息 完成 日期 填息 花費 日數
#      市 場    代碼    股票 名稱     股東會 日期     除息 交易日 除息 參考 價   填息 完成 日期 填息 花費 日數
# 0      市  0050   元大台灣50        NaN  '23/07/18  130.10  '23/11/21     87.0
# 1      市  0050   元大台灣50        NaN  '23/01/30  115.50  '23/01/30      1.0
# 2      市  0051  元大中型100        NaN  '23/11/16   68.60  '23/12/08     17.0
# 3      市  0052     富邦科技        NaN  '23/04/21  102.15  '23/05/25     24.0
# 4      市  0053     元大電子        NaN  '23/11/16   68.00  '23/12/14     21.0
# ...   ..   ...      ...        ...        ...     ...        ...      ...
# ...

# %%
import pandas as pd

# 讀取本地HTML文件中的表格
tables = pd.read_html('file:///Users/terrylin/Downloads/SaleMonDetail.html')

# 如果HTML文件來自網絡，先用requests獲取HTML字符串，然後再這樣讀取
# tables = pd.read_html(html_content)

# `tables`是一個包含所有找到的表格的DataFrame列表
for table in tables:
    print(table)
